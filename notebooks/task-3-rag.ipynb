# %% [markdown]
# # 📝 Task 3 – Retrieval-Augmented Generation (RAG) & Qualitative Evaluation
# 📘 Version: 2025-07-10
#
# Development and evaluation of a Retrieval-Augmented Generation (RAG) pipeline for **CrediTrust Financial’s Intelligent Complaint Analysis Initiative**. This notebook integrates semantic retrieval with prompt-guided language generation to enable automated question answering over consumer complaint narratives. The effectiveness of the RAG system is evaluated qualitatively using representative business questions.
#
# ---
#
# **Challenge:** B5W6 – Intelligent Complaint Analysis
# **Company:** CrediTrust Financial
# **Author:** Nabil Mohamed
# **Branch:** `task-3-rag`
# **Date:** July 2025
#
# ---
#
# ### 📌 This notebook covers:
# - Loading the precomputed ChromaDB vector store (`vector_store/chroma_db`)
# - Implementing a modular semantic retriever using embeddings
# - Designing prompt templates to guide the language model’s behavior
# - Generating answers using an LLM based on retrieved complaint excerpts
# - Running a qualitative evaluation on key business questions
# - Documenting performance via an evaluation table and thematic insights

# %%
# ------------------------------------------------------------------------------
# 🛠 Ensure Notebook Runs from Project Root (for src/ imports to work)
# ------------------------------------------------------------------------------

import os
import sys

# If running from /notebooks/, move up to project root
if os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")
    print("📂 Changed working directory to project root")

# Add project root to sys.path so `src/` modules can be imported
project_root = os.getcwd()
if project_root not in sys.path:
    sys.path.insert(0, project_root)
    print(f"✅ Added to sys.path: {project_root}")

# Optional: verify file presence to confirm we're in the right place
expected_path = "data/raw"
print(
    "📁 Output path ready"
    if os.path.exists(expected_path)
    else f"⚠️ Output path not found: {expected_path}"
)
# Out:
# 📂 Changed working directory to project root
# ✅ Added to sys.path: c:\Users\admin\Documents\GIT Repositories\b5-w6-intelligent-complaint-analysis-challenge
# 📁 Output path ready

# %% [markdown]
# ## 📦 Imports & Environment Setup
#
# This cell loads the core libraries required for implementing and evaluating the Retrieval-Augmented Generation (RAG) pipeline for intelligent complaint analysis. Imports are grouped by function:
#
# - **Data handling:** `pandas`, `numpy` — for managing evaluation questions, responses, and results tables.
# - **System & utilities:** `os`, `pathlib`, `warnings`, `time` — for path management, suppressing warnings, and measuring runtime.
# - **Visualization (optional):** `matplotlib`, `seaborn` — for visualizing evaluation metrics if needed.
# - **Embeddings & vector store:** `langchain.embeddings`, `langchain_community.vectorstores` — for embedding user questions and retrieving context from the ChromaDB vector store.
# - **Language model (optional):** LLM integration will be added to generate answers based on retrieved complaint excerpts.

# %%
# ---------------------------
# 📦 Imports & Environment Setup (Task 3 – RAG)
# ---------------------------

# ✅ Core Data Handling
import pandas as pd  # For handling evaluation tables and structured outputs
import numpy as np  # For embedding array management

# ✅ System & Utilities
import os  # For file and directory management
import warnings  # To suppress warnings
from pathlib import Path  # For cross-platform path management
import time  # For runtime measurement

# ✅ Visualization (Optional for Evaluation Summary)
import matplotlib.pyplot as plt  # For evaluation visuals
import seaborn as sns  # For enhanced plot styling

# ✅ Text Embedding and Vector Search
from langchain.embeddings import HuggingFaceEmbeddings  # For embedding user questions
from langchain_community.vectorstores import Chroma  # For loading vector store

# ✅ Language Model Generation (LLM placeholder: can use LangChain, OpenAI, HF pipeline, etc.)
# Example imports (uncomment based on LLM choice):
# from langchain.chat_models import ChatOpenAI
# from transformers import pipeline

# ✅ Configure Display & Plot Styles
pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", "{:,.2f}".format)
warnings.filterwarnings("ignore")
sns.set(style="whitegrid", context="notebook")

# %% [markdown]
# ## 📦 Load & Initialize ChromaDB Vector Store (Task 2 Output Reuse for Task 3 RAG)
#
# This step loads the precomputed ChromaDB vector store built in **Task 2**. The vector store contains semantically embedded complaint chunks from the CFPB dataset, enabling efficient retrieval of relevant complaints for Retrieval-Augmented Generation (RAG).
#
# - Uses the modular `ChromaLoader` class (`src/vector_store/chroma_loader.py`)
# - Loads the ChromaDB collection (`complaint_chunks`) from the persistent storage directory
# - Verifies the collection load status and outputs basic diagnostics (record count, storage path)
# - Raises explicit errors if the vector store is missing, inaccessible, or corrupted
# - Designed for robustness, reproducibility, and compatibility with downstream retrieval & generation
#
# This ensures the vector store is properly staged for real-time question answering and LLM integration in subsequent steps.

# %%
# ------------------------------------------------------------------------------
# 📦 Load ChromaDB Vector Store with Progress, Diagnostics & Time Estimation (Task 3)
# ------------------------------------------------------------------------------

# ✅ Import required components
from src.rag.chroma_loader import ChromaLoader  # Defensive loader class
from tqdm import tqdm  # For interactive progress bar
import time  # For runtime tracking

# ✅ Define inputs
vector_store_path = r"C:\Users\admin\Documents\GIT Repositories\b5-w6-intelligent-complaint-analysis-challenge\vector_store\chroma_db"
collection_name = "complaint_chunks"
embedding_model_name = "sentence-transformers/all-MiniLM-L6-v2"

# ✅ Initialize loader with defensive handling and progress
print("🚀 Initializing ChromaLoader...")
time.sleep(0.5)  # Brief pause for smooth UX

try:
    chroma_loader = ChromaLoader(
        persist_directory=vector_store_path,
        collection_name=collection_name,
        embedding_model_name=embedding_model_name,
    )
    print("✅ ChromaLoader initialized successfully.\n")
except Exception as e:
    print(f"❌ Loader initialization failed: {e}")
    chroma_loader = None

# ✅ Load vector store with progress bar
if chroma_loader:
    print("🔄 Loading ChromaDB vector store... Please wait.\n")
    start_time = time.time()

    with tqdm(
        total=1,
        desc="🔗 Loading Vector Store",
        bar_format="{l_bar}{bar} [ time left: {remaining} ]",
    ) as pbar:
        try:
            vector_store = chroma_loader.load_collection()  # Load the store
            pbar.update(1)  # Mark as complete
            elapsed_time = time.time() - start_time
            print(
                f"\n✅ Vector store loaded successfully in {elapsed_time:.2f} seconds."
            )
        except Exception as e:
            pbar.close()
            print(f"\n❌ Vector store loading failed: {e}")
            vector_store = None
else:
    vector_store = None
    print("⚠️ Skipped loading as ChromaLoader initialization failed.")
# Out:
# 🚀 Initializing ChromaLoader...
# ✅ ChromaLoader initialized successfully.
#
# 🔄 Loading ChromaDB vector store... Please wait.
# 🔗 Loading Vector Store: 100%|██████████ [ time left: 00:00 ]
# ✅ Chroma vector store 'complaint_chunks' loaded successfully with 147,194 documents.
# 📁 Storage location: C:\Users\admin\Documents\GIT Repositories\b5-w6-intelligent-complaint-analysis-challenge\vector_store\chroma_db
#
# ✅ Vector store loaded successfully in 7.30 seconds.

# %% [markdown]
# ## 📥 Define Business Question & Retrieval Parameters (Interactive Inputs for Task 3 RAG)
#
# This step captures the **user’s business question** and the **number of complaint chunks to retrieve (Top-K)** for the Retrieval-Augmented Generation (RAG) pipeline.
#
# - Uses interactive widgets (`ipywidgets`) for seamless question input and retrieval parameter selection
# - Allows flexible experimentation with different business questions and retrieval depths without modifying code
# - Ensures inputs are clearly defined, reproducible, and compatible with downstream semantic retrieval and prompt assembly
#
# This interactive approach enhances usability for both technical users and business stakeholders, supporting rapid exploration and qualitative evaluation of the RAG system.

# %%
# ------------------------------------------------------------------------------
# 📋 Preloaded Business Questions for Task 3 (Global Shared List)
# ------------------------------------------------------------------------------

# ✅ Persistent global list of preloaded questions for Task 3 evaluation
preloaded_questions = [
    "How are credit card disputes usually handled by the company?",
    "What are the most common complaints about personal loans?",
    "Why are customers dissatisfied with Buy Now, Pay Later services?",
    "What issues are reported with savings accounts?",
    "How do customers describe problems with money transfers?",
    "What are the top fraud-related complaints across all products?",
    "How do customers feel about interest rates on personal loans?",
    "What recurring issues are there with BNPL repayment terms?",
    "How often do customers report account access problems?",
    "What complaints suggest regulatory violations in any product?",
]

# %%
# ------------------------------------------------------------------------------
# 📥 Interactive Inputs (Dropdown + Text + Top-K) – Uses Shared Preloaded List
# ------------------------------------------------------------------------------

import ipywidgets as widgets
from IPython.display import display, clear_output

# ✅ Use preloaded_questions from global/module
input_state = {
    "user_question": preloaded_questions[0],  # Default first question from shared list
    "top_k": 5,
}

question_dropdown = widgets.Dropdown(
    options=preloaded_questions,
    value=input_state["user_question"],
    description="Select Question:",
    style={"description_width": "initial"},
    layout=widgets.Layout(width="80%"),
)

question_text = widgets.Text(
    value=input_state["user_question"],
    placeholder="Or type your own question here",
    description="Custom Question:",
    style={"description_width": "initial"},
    layout=widgets.Layout(width="80%"),
)

top_k_widget = widgets.IntSlider(
    value=input_state["top_k"],
    min=1,
    max=10,
    step=1,
    description="Top-K Chunks:",
    style={"description_width": "initial"},
    layout=widgets.Layout(width="50%"),
)


def on_input_change(change=None):
    clear_output(wait=True)
    display(question_dropdown, question_text, top_k_widget)

    chosen_question = (
        question_text.value.strip()
        if question_text.value.strip()
        else question_dropdown.value
    )
    input_state["user_question"] = chosen_question
    input_state["top_k"] = top_k_widget.value

    print(
        f"✅ Inputs captured:\n• Question: '{input_state['user_question']}'\n• Top-K: {input_state['top_k']}"
    )


question_dropdown.observe(on_input_change, names="value")
question_text.on_submit(on_input_change)
top_k_widget.observe(on_input_change, names="value")

display(question_dropdown, question_text, top_k_widget)
# Out:
# Dropdown(description='Select Question:', layout=Layout(width='80%'), options=('How are credit card disputes us…
# Text(value='How are credit card disputes usually handled by the company?', description='Custom Question:', lay…
# IntSlider(value=5, description='Top-K Chunks:', layout=Layout(width='50%'), max=10, min=1, style=SliderStyle(d…

# %% [markdown]
# ## 🔍 Retrieve Relevant Complaint Chunks Based on User Questions (Task 3 Retrieval)
#
# This step retrieves the most semantically relevant complaint excerpts from the precomputed ChromaDB vector store based on a user-supplied question.
#
# - Uses the modular `QuestionRetriever` class (`src/rag/retriever.py`)
# - Embeds the input question using the `all-MiniLM-L6-v2` transformer model
# - Performs vector similarity search over stored complaint embeddings
# - Returns top-k complaint chunks with associated metadata for downstream prompt assembly
#
# This step enables **contextual retrieval**, forming the foundation for Retrieval-Augmented Generation (RAG) and answer generation in subsequent steps.

# %%
# ------------------------------------------------------------------------------
# 🔍 Batch Retrieval for All Preloaded Business Questions (Task 3 – Retrieval Only)
# ------------------------------------------------------------------------------

# ✅ Import retriever module
from src.rag.retriever import QuestionRetriever

# ✅ Initialize retriever once with fixed Top-K (or you can make it dynamic per question)
try:
    retriever = QuestionRetriever(
        vector_store=vector_store,
        embedding_model_name="all-MiniLM-L6-v2",
        top_k=5,  # You can adjust this if you want
    )
    print("✅ QuestionRetriever initialized successfully.\n")
except Exception as e:
    print(f"❌ Failed to initialize retriever: {e}")
    retriever = None

# ✅ Run retrieval for each preloaded question in the list
if retriever:
    for idx, question in enumerate(preloaded_questions, 1):
        try:
            print(f"🔍 Question {idx}/{len(preloaded_questions)}:")
            print(f"➡️ {question}\n")

            # Run retrieval
            retrieved_chunks = retriever.retrieve(question)

            # Display number of chunks retrieved
            print(f"✅ Retrieved {len(retrieved_chunks)} complaint chunks.\n")

            # Show top 3 previews safely
            for i, chunk in enumerate(retrieved_chunks[:3], 1):
                doc_preview = (
                    chunk["document"][:300] + "..."
                    if len(chunk["document"]) > 300
                    else chunk["document"]
                )
                print(f"🔹 Result {i}: {doc_preview}")
                print(f"Metadata: {chunk['metadata']}\n")

            print("-" * 80 + "\n")

        except Exception as e:
            print(f"❌ Retrieval failed for question {idx}: {e}\n")

else:
    print("⚠️ Retrieval skipped: QuestionRetriever not available.")
# Out:
# ✅ QuestionRetriever initialized successfully.
#
# 🔍 Question 1/10:
# ➡️ How are credit card disputes usually handled by the company?
#
# ✅ Retrieved 5 complaint chunks.
#
# 🔹 Result 1: card company gets away with a charge thats in dispute.. that will go against someones credit score. they should take way that charge while in dispute.. if its truly a charge,. then put back on.. other credit card companies take the charge away until the dispute is final.
# Metadata: {'Complaint ID': 4383687, 'Chunk Index': 2, 'Product': 'Credit card or prepaid card'}
#
# 🔹 Result 2: card company gets away with a charge thats in dispute.. that will go against someones credit score. they should take way that charge while in dispute.. if its truly a charge,. then put back on.. other credit card companies take the charge away until the dispute is final.
# Metadata: {'Complaint ID': 4383687, 'Chunk Index': 2, 'Product': 'Credit card or prepaid card'}
#
# 🔹 Result 3: i'm suppose to do in this situation and the bank refusing to process the identical disputes properly, apply credits, stop the merchant from making the charges, and reissue the card.
# Metadata: {'Product': 'Credit card or prepaid card', 'Chunk Index': 3, 'Complaint ID': 4388043}
#
# --------------------------------------------------------------------------------
#
# 🔍 Question 2/10:
# ➡️ What are the most common complaints about personal loans?
#
# ✅ Retrieved 5 complaint chunks.
#
# 🔹 Result 1: policies so that they can not be sued. there are multiple xxxx complaints regarding this company. i urge to please look into them. i took a loan at a time of need, and i still find myself paying it 2 years later. they are draining my bank account every month. 24 months later paying 240 a month i hav...
# Metadata: {'Complaint ID': 8416836, 'Chunk Index': 2, 'Product': 'Payday loan, title loan, personal loan, or advance loan'}
#
# 🔹 Result 2: policies so that they can not be sued. there are multiple xxxx complaints regarding this company. i urge to please look into them. i took a loan at a time of need, and i still find myself paying it 2 years later. they are draining my bank account every month. 24 months later paying 240 a month i hav...
# Metadata: {'Complaint ID': 8416836, 'Product': 'Payday loan, title loan, personal loan, or advance loan', 'Chunk Index': 2}
#
# 🔹 Result 3: my credit ... im not the only one, there is a website of xxxx 's of complaints identical to mine in regards to castle payday consumer loans
# Metadata: {'Chunk Index': 5, 'Complaint ID': 1606863, 'Product': 'Consumer Loan'}
#
# --------------------------------------------------------------------------------
#
# 🔍 Question 3/10:
# ➡️ Why are customers dissatisfied with Buy Now, Pay Later services?
#
# ✅ Retrieved 5 complaint chunks.
#
# 🔹 Result 1: their customers like this unless it was always there intention to learn a customer in on false advertising, misrepresent the contract, falsify financial records of payment from their customers, and raise the interest so high that customers become life long slaves to their companies by forcing their ...
# Metadata: {'Product': 'Debt collection', 'Chunk Index': 38, 'Complaint ID': 7212368}
#
# 🔹 Result 2: their customers like this unless it was always there intention to learn a customer in on false advertising, misrepresent the contract, falsify financial records of payment from their customers, and raise the interest so high that customers become life long slaves to their companies by forcing their ...
# Metadata: {'Product': 'Debt collection', 'Complaint ID': 7212368, 'Chunk Index': 38}
#
# 🔹 Result 3: customers and that they treat loyal customers this way.
# Metadata: {'Chunk Index': 3, 'Complaint ID': 4204628, 'Product': 'Credit card or prepaid card'}
#
# --------------------------------------------------------------------------------
#
# 🔍 Question 4/10:
# ➡️ What issues are reported with savings accounts?
#
# ✅ Retrieved 5 complaint chunks.
#
# 🔹 Result 1: a few. i have had various accounts my entire life with no issues to report, now, my banking has been an abomination.
# Metadata: {'Complaint ID': 2981792, 'Product': 'Checking or savings account', 'Chunk Index': 2}
#
# 🔹 Result 2: a few. i have had various accounts my entire life with no issues to report, now, my banking has been an abomination.
# Metadata: {'Chunk Index': 2, 'Product': 'Checking or savings account', 'Complaint ID': 2981792}
#
# 🔹 Result 3: significant financial losses for many, breaching the consumer financial protection act and the truth in savings act. i seek redress for the misleading practices and failure to fulfill their regarding the deceptive practices related to their 360 " high yield interest '' savings accounts. capital one ...
# Metadata: {'Product': 'Checking or savings account', 'Chunk Index': 1, 'Complaint ID': 11646640}
#
# --------------------------------------------------------------------------------
#
# 🔍 Question 5/10:
# ➡️ How do customers describe problems with money transfers?
#
# ✅ Retrieved 5 complaint chunks.
#
# 🔹 Result 1: money is transferred successfully! this is the slowest company i have ever used the service of even to respond to the issues i just demand my money back and will not use xxxx xxxx ever because they do not have a proper system of resolving their customers ' issues.
# Metadata: {'Chunk Index': 1, 'Product': 'Money transfer, virtual currency, or money service', 'Complaint ID': 3033202}
#
# 🔹 Result 2: money is transferred successfully! this is the slowest company i have ever used the service of even to respond to the issues i just demand my money back and will not use xxxx xxxx ever because they do not have a proper system of resolving their customers ' issues.
# Metadata: {'Chunk Index': 1, 'Complaint ID': 3033202, 'Product': 'Money transfer, virtual currency, or money service'}
#
# 🔹 Result 3: transfers in the last three years without issues. the same problem happened with another transfer xxxx sent in xxxx. for that transfer moneygram eventually paid and refunded the money. i know the outcome is wrong but the agent insisted the money had not been paid though it was paid. i have an email ...
# Metadata: {'Chunk Index': 1, 'Complaint ID': 6003701, 'Product': 'Money transfer, virtual currency, or money service'}
#
# --------------------------------------------------------------------------------
#
# 🔍 Question 6/10:
# ➡️ What are the top fraud-related complaints across all products?
#
# ✅ Retrieved 5 complaint chunks.
#
# 🔹 Result 1: theft and financial fraud, not to mention for their actual customers.
# Metadata: {'Product': 'Credit card or prepaid card', 'Complaint ID': 4176923, 'Chunk Index': 2}
#
# 🔹 Result 2: theft and financial fraud, not to mention for their actual customers.
# Metadata: {'Chunk Index': 2, 'Product': 'Credit card or prepaid card', 'Complaint ID': 4176923}
#
# 🔹 Result 3: though somehow goes undetected. i repeat that even the most basic measures to validate checks and or detect abnormal activity would have immediately caught this issue. their responses to me only sited the fact that i did not see the fraud. they never once responded to the fact that they failed to pr...
# Metadata: {'Chunk Index': 9, 'Product': 'Checking or savings account', 'Complaint ID': 5091457}
#
# --------------------------------------------------------------------------------
#
# 🔍 Question 7/10:
# ➡️ How do customers feel about interest rates on personal loans?
#
# ✅ Retrieved 5 complaint chunks.
#
# 🔹 Result 1: the interest rates are ridiculous. i 've asked for financial help multiple times and they offer nothing. private loans are the worst! i can not repay the amounts when the interest is ridiculously high. highly irritated with the bondage of private loans.
# Metadata: {'Product': 'Student loan', 'Chunk Index': 0, 'Complaint ID': 2003976}
#
# 🔹 Result 2: the interest rates are ridiculous. i 've asked for financial help multiple times and they offer nothing. private loans are the worst! i can not repay the amounts when the interest is ridiculously high. highly irritated with the bondage of private loans.
# Metadata: {'Product': 'Student loan', 'Chunk Index': 0, 'Complaint ID': 2003976}
#
# 🔹 Result 3: situations? they have to understand that their customers are paying 3 times as much in monthly payments as a normal consumer would. i understand these loans are risky but at the same time, but 510.00 a month for my vehicle is outrageous. i was promised when i got to the car that i could refinance fo...
# Metadata: {'Chunk Index': 3, 'Product': 'Vehicle loan or lease', 'Complaint ID': 2467186}
#
# --------------------------------------------------------------------------------
#
# 🔍 Question 8/10:
# ➡️ What recurring issues are there with BNPL repayment terms?
#
# ✅ Retrieved 5 complaint chunks.
#
# 🔹 Result 1: talk to anyone regarding my concerns and that my repayment plan has again been changed to an income based repayment plan.
# Metadata: {'Complaint ID': 7578750, 'Product': 'Student loan', 'Chunk Index': 3}
#
# 🔹 Result 2: talk to anyone regarding my concerns and that my repayment plan has again been changed to an income based repayment plan.
# Metadata: {'Chunk Index': 3, 'Product': 'Student loan', 'Complaint ID': 7578750}
#
# 🔹 Result 3: much higher payment they 've put me under. this is also because they said that i have to make a full standard payment amount for one additional month in order to switch from one income based repayment plan to another, which seems like it should not be the case. if an individual needs to switch from ...
# Metadata: {'Chunk Index': 5, 'Product': 'Student loan', 'Complaint ID': 2648334}
#
# --------------------------------------------------------------------------------
#
# 🔍 Question 9/10:
# ➡️ How often do customers report account access problems?
#
# ✅ Retrieved 5 complaint chunks.
#
# 🔹 Result 1: a few. i have had various accounts my entire life with no issues to report, now, my banking has been an abomination.
# Metadata: {'Complaint ID': 2981792, 'Product': 'Checking or savings account', 'Chunk Index': 2}
#
# 🔹 Result 2: a few. i have had various accounts my entire life with no issues to report, now, my banking has been an abomination.
# Metadata: {'Chunk Index': 2, 'Product': 'Checking or savings account', 'Complaint ID': 2981792}
#
# 🔹 Result 3: very least. we are consistently given changing information. no call to the office of the consumer advocate provides the same information, and it is difficult to get responses at all. they claim repeatedly that they have " investigated '' the account, but have not ever produced findings to explain wh...
# Metadata: {'Product': 'Student loan', 'Complaint ID': 3489384, 'Chunk Index': 4}
#
# --------------------------------------------------------------------------------
#
# 🔍 Question 10/10:
# ➡️ What complaints suggest regulatory violations in any product?
#
# ✅ Retrieved 5 complaint chunks.
#
# 🔹 Result 1: i have prepared stating the violations from tila, ecoa, etc. congress wrote these laws to help and protect consumers such as myself. i have also submitted a complaint to the attorney generals and the federal trade commission. my concerns continue to be ignored and i havent heard anything back from d...
# Metadata: {'Product': 'Credit card or prepaid card', 'Chunk Index': 1, 'Complaint ID': 6343357}
#
# 🔹 Result 2: i will have no choice but to pursue further steps with additional regulatory bodies to ensure compliance and accountability. please confirm receipt of this complaint and provide a timeline for resolution. should additional information be required, i am happy to provide it. thank you for your attenti...
# Metadata: {'Product': 'Checking or savings account', 'Chunk Index': 4, 'Complaint ID': 11123598}
#
# 🔹 Result 3: act and regulation e. these actions caused major inconveniences and financial loss. i seek appropriate help for these violations.
# Metadata: {'Chunk Index': 1, 'Complaint ID': 12015193, 'Product': 'Money transfer, virtual currency, or money service'}
#
# --------------------------------------------------------------------------------

# %% [markdown]
# ## ✏️ Assemble RAG Prompt Using Retrieved Complaint Chunks (Task 3 Prompt Engineering)
#
# This step assembles a high-quality prompt for the language model by combining:
#
# - The user’s original question
# - The top-k retrieved complaint chunks from ChromaDB
#
# It uses the modular `PromptEngineer` class (`src/rag/prompt_template.py`) to structure the context in a clean, LLM-friendly format. This ensures that downstream answer generation is both **accurate** and **grounded** in real complaint data.

# %%
# ------------------------------------------------------------------------------
# ✏️ Batch Assemble RAG Prompts for All Preloaded Questions (Task 3)
# ------------------------------------------------------------------------------

# ✅ Import PromptEngineer
from src.rag.prompt_template import PromptEngineer

# ✅ Initialize prompt engineer
prompt_engineer = PromptEngineer(max_context_length=3000)

# ✅ Run prompt assembly for each preloaded question
for idx, question in enumerate(preloaded_questions, 1):
    try:
        print(f"📝 Assembling Prompt for Question {idx}/{len(preloaded_questions)}")
        print(f"➡️ {question}\n")

        # ✅ Step 1: Retrieve complaint chunks
        retrieved_chunks = retriever.retrieve(question)

        if not retrieved_chunks:
            print("⚠️ No complaint chunks retrieved. Skipping this question.\n")
            continue  # Skip to next question

        # ✅ Step 2: Build prompt from retrieved chunks
        prompt = prompt_engineer.build_prompt(
            question=question, retrieved_chunks=retrieved_chunks
        )

        print("✅ Prompt assembled successfully.\n")
        print("📝 Prompt Preview (First 800 characters):\n")
        print(prompt[:800])  # Display limited preview to avoid notebook clutter

        print("-" * 80 + "\n")

    except Exception as e:
        print(f"❌ Prompt assembly failed for Question {idx}: {e}\n")
# Out:
# 📝 Assembling Prompt for Question 1/10
# ➡️ How are credit card disputes usually handled by the company?
#
# ✅ Prompt assembled successfully.
#
# 📝 Prompt Preview (First 800 characters):
#
# You are an impartial financial assistant for CrediTrust Financial. Your task is to answer business questions using only the information provided in the retrieved customer complaint narratives.
#
# Instructions:
# - Base your answer strictly on the retrieved context below.
# - Do not add information, speculate, or make assumptions beyond the given context.
# - If the context does not contain enough information to confidently answer the question, clearly say:
#   **"The available complaint data does not provide enough information to answer this question."**
#
# Retrieved Complaint Narratives:
# card company gets away with a charge thats in dispute.. that will go against someones credit score. they should take way that charge while in dispute.. if its truly a charge,. then put back on.. other credit card c
# --------------------------------------------------------------------------------
#
# 📝 Assembling Prompt for Question 2/10
# ➡️ What are the most common complaints about personal loans?
#
# ✅ Prompt assembled successfully.
#
# 📝 Prompt Preview (First 800 characters):
#
# You are an impartial financial assistant for CrediTrust Financial. Your task is to answer business questions using only the information provided in the retrieved customer complaint narratives.
#
# Instructions:
# - Base your answer strictly on the retrieved context below.
# - Do not add information, speculate, or make assumptions beyond the given context.
# - If the context does not contain enough information to confidently answer the question, clearly say:
#   **"The available complaint data does not provide enough information to answer this question."**
#
# Retrieved Complaint Narratives:
# policies so that they can not be sued. there are multiple xxxx complaints regarding this company. i urge to please look into them. i took a loan at a time of need, and i still find myself paying it 2 years later. t
# --------------------------------------------------------------------------------
#
# 📝 Assembling Prompt for Question 3/10
# ➡️ Why are customers dissatisfied with Buy Now, Pay Later services?
#
# ✅ Prompt assembled successfully.
#
# 📝 Prompt Preview (First 800 characters):
#
# You are an impartial financial assistant for CrediTrust Financial. Your task is to answer business questions using only the information provided in the retrieved customer complaint narratives.
#
# Instructions:
# - Base your answer strictly on the retrieved context below.
# - Do not add information, speculate, or make assumptions beyond the given context.
# - If the context does not contain enough information to confidently answer the question, clearly say:
#   **"The available complaint data does not provide enough information to answer this question."**
#
# Retrieved Complaint Narratives:
# their customers like this unless it was always there intention to learn a customer in on false advertising, misrepresent the contract, falsify financial records of payment from their customers, and raise the intere
# --------------------------------------------------------------------------------
#
# 📝 Assembling Prompt for Question 4/10
# ➡️ What issues are reported with savings accounts?
#
# ✅ Prompt assembled successfully.
#
# 📝 Prompt Preview (First 800 characters):
#
# You are an impartial financial assistant for CrediTrust Financial. Your task is to answer business questions using only the information provided in the retrieved customer complaint narratives.
#
# Instructions:
# - Base your answer strictly on the retrieved context below.
# - Do not add information, speculate, or make assumptions beyond the given context.
# - If the context does not contain enough information to confidently answer the question, clearly say:
#   **"The available complaint data does not provide enough information to answer this question."**
#
# Retrieved Complaint Narratives:
# a few. i have had various accounts my entire life with no issues to report, now, my banking has been an abomination.
# ---
# a few. i have had various accounts my entire life with no issues to report, now, my banking h
# --------------------------------------------------------------------------------
#
# 📝 Assembling Prompt for Question 5/10
# ➡️ How do customers describe problems with money transfers?
#
# ✅ Prompt assembled successfully.
#
# 📝 Prompt Preview (First 800 characters):
#
# You are an impartial financial assistant for CrediTrust Financial. Your task is to answer business questions using only the information provided in the retrieved customer complaint narratives.
#
# Instructions:
# - Base your answer strictly on the retrieved context below.
# - Do not add information, speculate, or make assumptions beyond the given context.
# - If the context does not contain enough information to confidently answer the question, clearly say:
#   **"The available complaint data does not provide enough information to answer this question."**
#
# Retrieved Complaint Narratives:
# money is transferred successfully! this is the slowest company i have ever used the service of even to respond to the issues i just demand my money back and will not use xxxx xxxx ever because they do not have a pr
# --------------------------------------------------------------------------------
#
# 📝 Assembling Prompt for Question 6/10
# ➡️ What are the top fraud-related complaints across all products?
#
# ✅ Prompt assembled successfully.
#
# 📝 Prompt Preview (First 800 characters):
#
# You are an impartial financial assistant for CrediTrust Financial. Your task is to answer business questions using only the information provided in the retrieved customer complaint narratives.
#
# Instructions:
# - Base your answer strictly on the retrieved context below.
# - Do not add information, speculate, or make assumptions beyond the given context.
# - If the context does not contain enough information to confidently answer the question, clearly say:
#   **"The available complaint data does not provide enough information to answer this question."**
#
# Retrieved Complaint Narratives:
# theft and financial fraud, not to mention for their actual customers.
# ---
# theft and financial fraud, not to mention for their actual customers.
# ---
# though somehow goes undetected. i repeat that even the most basic
# --------------------------------------------------------------------------------
#
# 📝 Assembling Prompt for Question 7/10
# ➡️ How do customers feel about interest rates on personal loans?
#
# ✅ Prompt assembled successfully.
#
# 📝 Prompt Preview (First 800 characters):
#
# You are an impartial financial assistant for CrediTrust Financial. Your task is to answer business questions using only the information provided in the retrieved customer complaint narratives.
#
# Instructions:
# - Base your answer strictly on the retrieved context below.
# - Do not add information, speculate, or make assumptions beyond the given context.
# - If the context does not contain enough information to confidently answer the question, clearly say:
#   **"The available complaint data does not provide enough information to answer this question."**
#
# Retrieved Complaint Narratives:
# the interest rates are ridiculous. i 've asked for financial help multiple times and they offer nothing. private loans are the worst! i can not repay the amounts when the interest is ridiculously high. highly irrit
# --------------------------------------------------------------------------------
#
# 📝 Assembling Prompt for Question 8/10
# ➡️ What recurring issues are there with BNPL repayment terms?
#
# ✅ Prompt assembled successfully.
#
# 📝 Prompt Preview (First 800 characters):
#
# You are an impartial financial assistant for CrediTrust Financial. Your task is to answer business questions using only the information provided in the retrieved customer complaint narratives.
#
# Instructions:
# - Base your answer strictly on the retrieved context below.
# - Do not add information, speculate, or make assumptions beyond the given context.
# - If the context does not contain enough information to confidently answer the question, clearly say:
#   **"The available complaint data does not provide enough information to answer this question."**
#
# Retrieved Complaint Narratives:
# talk to anyone regarding my concerns and that my repayment plan has again been changed to an income based repayment plan.
# ---
# talk to anyone regarding my concerns and that my repayment plan has again been changed t
# --------------------------------------------------------------------------------
#
# 📝 Assembling Prompt for Question 9/10
# ➡️ How often do customers report account access problems?
#
# ✅ Prompt assembled successfully.
#
# 📝 Prompt Preview (First 800 characters):
#
# You are an impartial financial assistant for CrediTrust Financial. Your task is to answer business questions using only the information provided in the retrieved customer complaint narratives.
#
# Instructions:
# - Base your answer strictly on the retrieved context below.
# - Do not add information, speculate, or make assumptions beyond the given context.
# - If the context does not contain enough information to confidently answer the question, clearly say:
#   **"The available complaint data does not provide enough information to answer this question."**
#
# Retrieved Complaint Narratives:
# a few. i have had various accounts my entire life with no issues to report, now, my banking has been an abomination.
# ---
# a few. i have had various accounts my entire life with no issues to report, now, my banking h
# --------------------------------------------------------------------------------
#
# 📝 Assembling Prompt for Question 10/10
# ➡️ What complaints suggest regulatory violations in any product?
#
# ✅ Prompt assembled successfully.
#
# 📝 Prompt Preview (First 800 characters):
#
# You are an impartial financial assistant for CrediTrust Financial. Your task is to answer business questions using only the information provided in the retrieved customer complaint narratives.
#
# Instructions:
# - Base your answer strictly on the retrieved context below.
# - Do not add information, speculate, or make assumptions beyond the given context.
# - If the context does not contain enough information to confidently answer the question, clearly say:
#   **"The available complaint data does not provide enough information to answer this question."**
#
# Retrieved Complaint Narratives:
# i have prepared stating the violations from tila, ecoa, etc. congress wrote these laws to help and protect consumers such as myself. i have also submitted a complaint to the attorney generals and the federal trade
# --------------------------------------------------------------------------------

# %% [markdown]
# ## 📝 Generate LLM Answer Using Gemini Free API (Task 3 Answer Generation)
#
# This step generates an automated answer to the business question using the previously assembled RAG prompt and Google's **Gemini 1.5 Flash** language model via the **free-tier API**.
#
# - Uses the modular `AnswerGenerator` class (`src/rag/answer_generator.py`)
# - Currently connected to **Google Gemini Free API** for zero-cost, no-billing inference
# - Designed to be model-agnostic: can be easily swapped for **OpenAI**, **Hugging Face**, or other providers as needed
# - Ensures flexibility, reproducibility, and readiness for downstream **qualitative evaluation** of answer quality and relevance
#
# This enables fully automated, context-driven response generation based on real consumer complaint narratives.

# %%
# ------------------------------------------------------------------------------
# 🔄 Reload AnswerGenerator Module (Notebook Live Reload - Task 3)
# ------------------------------------------------------------------------------

import importlib  # For dynamic module reloading

# ✅ Import your module
import src.rag.answer_generator as answer_generator_module

# ✅ Reload to ensure latest changes are picked up
importlib.reload(answer_generator_module)

# ✅ Pull updated class into notebook namespace
AnswerGenerator = answer_generator_module.AnswerGenerator

print("✅ AnswerGenerator module reloaded and ready.")
# Out:
# ✅ AnswerGenerator module reloaded and ready.

# %%
# ------------------------------------------------------------------------------
# 📝 Batch Generate LLM Answers for All Preloaded Prompts (Task 3)
# ------------------------------------------------------------------------------

# ✅ Import AnswerGenerator class
from src.rag.answer_generator import AnswerGenerator

# ✅ Define Gemini API key (secure in production!)
gemini_api_key = "AIzaSyDM6YAwR1ajk6fzhGepD0q7sOtVqrnBuMs"

# ✅ Initialize AnswerGenerator
answer_generator = AnswerGenerator(api_key=gemini_api_key, model="gemini-2.5-flash")

# ✅ Optional: Store prompts and answers for review/report
batch_results = []

# ✅ Loop through all preloaded questions
for idx, question in enumerate(preloaded_questions, 1):
    try:
        print(f"📝 Generating Answer for Question {idx}/{len(preloaded_questions)}")
        print(f"➡️ {question}\n")

        # Step 1: Retrieve chunks
        retrieved_chunks = retriever.retrieve(question)

        if not retrieved_chunks:
            print("⚠️ No complaint chunks retrieved. Skipping this question.\n")
            continue  # Skip to next

        # Step 2: Assemble prompt
        prompt = prompt_engineer.build_prompt(question, retrieved_chunks)

        # Step 3: Generate answer using Gemini
        answer = answer_generator.generate_answer(prompt)

        # Step 4: Store results
        batch_results.append(
            {
                "question": question,
                "retrieved_chunks": retrieved_chunks,
                "prompt": prompt,
                "answer": answer,
            }
        )

        print("✅ Answer generated successfully.\n")
        print(answer[:800])  # Preview only
        print("-" * 80 + "\n")

    except Exception as e:
        print(f"❌ Failed to generate answer for Question {idx}: {e}\n")

print(f"✅ Batch generation completed: {len(batch_results)} successful runs.\n")
# Out:
# 📝 Generating Answer for Question 1/10
# ➡️ How are credit card disputes usually handled by the company?
#
# ✅ Answer generated successfully.
#
# Based on the complaints, credit card disputes are usually handled as follows:
#
# *   The company does not remove the disputed charge from the account while it is under investigation.
# *   The company conducts an investigation into the disputes, initially providing a timeframe for completion, but these deadlines are subject to extensions.
# *   Customers report difficulty getting assistance when calling to discuss disputes.
# *   Customers also state that the bank is refusing to process disputes properly, apply credits, stop merchant charges, or reissue cards.
# --------------------------------------------------------------------------------
#
# 📝 Generating Answer for Question 2/10
# ➡️ What are the most common complaints about personal loans?
#
# ✅ Answer generated successfully.
#
# Based on the retrieved complaint narratives, the most common complaints about loans are:
#
# *   Loans taking an excessively long time to repay (e.g., 2 years).
# *   Loans draining bank accounts every month.
# *   Paying back more than double the initially borrowed amount.
# *   Issues related to credit (specifically mentioned in relation to "castle payday consumer loans").
# *   Loan amounts being too small (e.g., "barely over 2500.00").
# --------------------------------------------------------------------------------
#
# 📝 Generating Answer for Question 3/10
# ➡️ Why are customers dissatisfied with Buy Now, Pay Later services?
#
# ✅ Answer generated successfully.
#
# The available complaint data does not provide enough information to answer this question. The complaints discuss issues such as false advertising, misrepresentation of contracts, falsifying financial records of payment, high interest rates, and being forced into debt by illegal methods, but they do not specifically link these grievances to "Buy Now, Pay Later" services.
# --------------------------------------------------------------------------------
#
# 📝 Generating Answer for Question 4/10
# ➡️ What issues are reported with savings accounts?
#
# ✅ Answer generated successfully.
#
# Issues reported with savings accounts include:
# *   Deceptive practices related to 360 "high yield interest" savings accounts.
# *   Misrepresentation of the 360 savings account as having one of the nation's highest interest rates.
# *   Failure to notify accountholders about superior rates offered by the 360 performance savings.
# *   Breaching the Consumer Financial Protection Act and the Truth in Savings Act.
# *   Changing the product used to advertise savings account rates and replacing it with something identical in all but name, but with lower interest rates.
# *   Customer service representatives being unable to easily spot the difference in these changed products.
# *   Significant loss of interest income over time.
# --------------------------------------------------------------------------------
#
# 📝 Generating Answer for Question 5/10
# ➡️ How do customers describe problems with money transfers?
#
# ✅ Answer generated successfully.
#
# Customers describe problems with money transfers as:
# *   Slow company response to issues.
# *   Lack of a proper system for resolving customer issues.
# *   Agents insisting money had not been paid when it actually was.
# *   "Something wrong with MoneyGram systems," including a refusal to listen or investigate these occurrences.
# *   General "issues with money" and a lack of customer service to get them resolved.
# --------------------------------------------------------------------------------
#
# 📝 Generating Answer for Question 6/10
# ➡️ What are the top fraud-related complaints across all products?
#
# ✅ Answer generated successfully.
#
# Based on the retrieved complaint narratives, the top fraud-related complaints include:
#
# *   Undetected theft and financial fraud despite basic measures to validate checks and detect abnormal activity.
# *   Failure to provide even minimal fraud protection and monitoring.
# *   Blaming the customer for fraud, despite advertising ultimate fraud protection.
# --------------------------------------------------------------------------------
#
# 📝 Generating Answer for Question 7/10
# ➡️ How do customers feel about interest rates on personal loans?
#
# ✅ Answer generated successfully.
#
# Customers feel that the interest rates on their loans, particularly private loans, are "ridiculous" and "ridiculously high." They state that these rates make it difficult to repay the amounts and cause "great financial pain."
# --------------------------------------------------------------------------------
#
# 📝 Generating Answer for Question 8/10
# ➡️ What recurring issues are there with BNPL repayment terms?
#
# ✅ Answer generated successfully.
#
# The available complaint data does not provide enough information to answer this question.
# --------------------------------------------------------------------------------
#
# 📝 Generating Answer for Question 9/10
# ➡️ How often do customers report account access problems?
#
# ✅ Answer generated successfully.
#
# The available complaint data does not provide enough information to answer this question.
# --------------------------------------------------------------------------------
#
# 📝 Generating Answer for Question 10/10
# ➡️ What complaints suggest regulatory violations in any product?
#
# ✅ Answer generated successfully.
#
# The following complaints suggest regulatory violations:
#
# *   One complaint states "violations from tila, ecoa, etc." and mentions submitting a complaint to the Attorney Generals and the Federal Trade Commission.
# *   Another complaint indicates "no choice but to pursue further steps with additional regulatory bodies to ensure compliance and accountability."
# *   A third complaint refers to "act and regulation e" and states, "these actions caused major inconveniences and financial loss. i seek appropriate help for these violations."
# *   A fourth complaint asserts, "the regulations must be followed, the xxxx xxxx xxxx act in particular."
# --------------------------------------------------------------------------------
#
# ✅ Batch generation completed: 10 successful runs.

# %% [markdown]
# ## 🏁 Qualitative Evaluation of RAG Outputs (Task 3 Evaluation)
#
# This step captures a **structured qualitative assessment** of the Retrieval-Augmented Generation (RAG) pipeline outputs based on key business-aligned criteria:
#
# - **Relevance:** Does the generated answer align with the retrieved complaint evidence?
# - **Accuracy:** Is the answer factually correct and free from hallucination?
# - **Completeness:** Does the answer fully and directly address the business question?
#
# The evaluation results are stored in an interactive table to support:
# - Transparent reporting for stakeholders
# - Iterative refinement of prompt design and retrieval quality
# - Future quantitative scoring if needed
#
# This ensures that the RAG system meets both **technical performance** and **business credibility** requirements.

# %%
# ------------------------------------------------------------------------------
# 🏁 Batch Add RAG Outputs to Qualitative Evaluation Table with Auto-Evaluation
# ------------------------------------------------------------------------------

# ✅ Import QualitativeEvaluator if not already imported
from src.rag.qualitative_evaluator import QualitativeEvaluator

# ✅ Initialize evaluator if not already created earlier
try:
    evaluator
except NameError:
    evaluator = QualitativeEvaluator()

# ✅ Run evaluation for each batch result
for idx, result in enumerate(batch_results, 1):
    try:
        question = result["question"]
        retrieved_chunks = result["retrieved_chunks"]
        answer = result["answer"]

        # ✅ Build short context from top retrieved chunks (safe length)
        evidence_context = "\n---\n".join(
            [chunk.get("document", "")[:300] for chunk in retrieved_chunks[:3]]
        )

        # ✅ Run automated evaluation using AnswerGenerator
        evaluation = answer_generator.evaluate_answer(
            question=question, context=evidence_context, generated_answer=answer
        )

        # ✅ Extract key evaluation metrics
        relevance = evaluation.get("Relevance", None)
        accuracy = evaluation.get("Accuracy", None)
        completeness = evaluation.get("Completeness", None)
        comments = evaluation.get("Comments", None)
        quality_score = evaluation.get("Quality Score", None)

        # ✅ Add record to evaluator
        evaluator.add_entry(
            question=question,
            retrieved_chunks=retrieved_chunks,
            generated_answer=answer,
            relevance=relevance,
            accuracy=accuracy,
            completeness=completeness,
            comments=comments,
        )

        print(
            f"✅ Evaluation {idx}/{len(batch_results)} added (Quality Score: {quality_score})"
        )

    except Exception as e:
        print(f"❌ Evaluation failed for Question {idx}: {e}")

# ✅ Display full evaluation table at the end
evaluator.display()
# Out:
# ✅ Evaluation 1/10 added (Quality Score: 2)
# ✅ Evaluation 2/10 added (Quality Score: 55)
# ✅ Evaluation 3/10 added (Quality Score: 5)
# ✅ Evaluation 4/10 added (Quality Score: 1.5)
# ✅ Evaluation 5/10 added (Quality Score: 3/5)
# ✅ Evaluation 6/10 added (Quality Score: 2)
# ✅ Evaluation 7/10 added (Quality Score: 5/5)
# ✅ Evaluation 8/10 added (Quality Score: 5)
# ✅ Evaluation 9/10 added (Quality Score: 5/5)
# ✅ Evaluation 10/10 added (Quality Score: 3/5)
#                                             Question  \
# 0  How are credit card disputes usually handled b...
# 1  What are the most common complaints about pers...
# 2  Why are customers dissatisfied with Buy Now, P...
# 3    What issues are reported with savings accounts?
# 4  How do customers describe problems with money ...
# 5  What are the top fraud-related complaints acro...
# 6  How do customers feel about interest rates on ...
# 7  What recurring issues are there with BNPL repa...
# 8  How often do customers report account access p...
# 9  What complaints suggest regulatory violations ...
#
#                         Retrieved Evidence (Preview)  \
# 0  card company gets away with a charge thats in ...
# 1  policies so that they can not be sued. there a...
# 2  their customers like this unless it was always...
# 3  a few. i have had various accounts my entire l...
# 4  money is transferred successfully! this is the...
# 5  theft and financial fraud, not to mention for ...
# 6  the interest rates are ridiculous. i 've asked...
# 7  talk to anyone regarding my concerns and that ...
# 8  a few. i have had various accounts my entire l...
# 9  i have prepared stating the violations from ti...
#
#                                     Generated Answer  \
# 0  Based on the complaints, credit card disputes ...
# 1  Based on the retrieved complaint narratives, t...
# 2  The available complaint data does not provide ...
# 3  Issues reported with savings accounts include:...
# 4  Customers describe problems with money transfe...
# 5  Based on the retrieved complaint narratives, t...
# 6  Customers feel that the interest rates on thei...
# 7  The available complaint data does not provide ...
# 8  The available complaint data does not provide ...
# 9  The following complaints suggest regulatory vi...
#
#                                      Relevance (✅/❌)  \
# 0                                               High
# 1  The answer directly addresses the question abo...
# 2                                               High
# 3                                               High
# 4  Yes, the answer directly addresses how custome...
# 5                                               High
# 6  The answer is highly relevant to the question,...
# 7                                               High
# 8  The generated answer is highly relevant as it ...
# 9  The generated answer is highly relevant to the...
#
#                                       Accuracy (✅/❌)  \
# 0                                                Low
# 1  The answer accurately identifies two complaint...
# 2                                               High
# 3                                                Low
# 4  The first three bullet points are accurate and...
# 5                                                Low
# 6  The answer is accurate. It correctly quotes se...
# 7                                           Accurate
# 8  The generated answer is accurate. The retrieve...
# 9  The first three points are accurately extracte...
#
#                                   Completeness (✅/❌)  \
# 0                                            Partial
# 1  The answer identifies the core complaints pres...
# 2                                               High
# 3                                             Medium
# 4  The answer captures the specific descriptions ...
# 5                                               Fair
# 6  The answer is complete. It captures the core s...
# 7                                           Complete
# 8  The answer is complete because it fully addres...
# 9  The answer identifies all three relevant compl...
#
#                                   Evaluator Comments
# 0  The answer accurately states that the company ...
# 1  The AI successfully extracts some of the key c...
# 2  The generated answer is excellent. It accurate...
# 3  The answer accurately identifies some issues d...
# 4  The answer successfully extracts several key d...
# 5  The answer accurately identifies two types of ...
# 6  The AI-generated answer is excellent. It preci...
# 7  The question asks about 'BNPL repayment terms'...
# 8  The AI correctly identifies that the provided ...
# 9  The AI successfully identified and extracted t...
